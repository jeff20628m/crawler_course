# %% [markdown]
# # crawler

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import time
## 因為大多為中文網站 所以必須要改decode

#html_bs = urlopen("https://find.ruten.com.tw/c/00090004").read().decode('utf-8')
html_re = requests.get("https://find.ruten.com.tw/c/00090004")
html_re.encoding = 'UTF-8'
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
html_sky = requests.get("https://www.tripadvisor.com.tw/Hotels-g293913-Taipei-Hotels.html")
html_sky.encoding = 'UTF-8'
soup_sky = BeautifulSoup(html_sky.text, 'html.parser')

# %%
soup_sky.find_all(class_ = "ui_column is-narrow title_wrap")[0].a['href']
# Out:
# '/Hotel_Review-g13806951-d3134481-Reviews-Via_Hotel-Wanhua_Taipei.html'

# %%
# requests 這個 python library 有很方便的 header 和 cookie 支援


headers = {
    # User agent 路邊隨意撿一個來用

    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36',
}

cookies = {
    # 就是這個光啦

    '_ts_id':  '999999999999999999', 
}

html_re = requests.get('https://goods.ruten.com.tw/item/show?21922589170747', headers=headers, cookies=cookies)
html_re.encoding = 'UTF-8'

# %%
soup = BeautifulSoup(html_re.text,'html.parser')   ### html.parser python 標準方式

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-TW" xml:lang="zh-TW" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ0406】《約翰家庭百貨 - 露天拍賣</title>
# <meta content="500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ0406】《約翰家庭百貨" name="description">
# <meta content="500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ0406】《約翰家庭百貨 - 露天拍賣" itemprop="name"/>
# <meta content="500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ0406】《約翰家庭百貨" itemprop="description"/>
# <meta content="https://img.ruten.com.tw/s1/3/9c/3b/21922589170747_949.jpg" itemprop="image"/>
# <meta content="500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ0406】《約翰家庭百貨 21922589170747 | 露天拍賣-台灣 NO.1 拍賣網站" property="og:title">
# ...

# %%
data = soup.select('script')[0].text.strip()

# %%
import json
jd = json.loads(data)

# %%
jd
# Out:
# {'@context': 'http://schema.org/',
#  '@type': 'Product',
#  'name': '500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ0406】《約翰家庭百貨',
#  'image': 'https://img.ruten.com.tw/s1/3/9c/3b/21922589170747_949.jpg',
#  'description': '直購價：149元。物品狀態：全新。支付方式包含PChomePay支付連、銀行或郵局轉帳、郵局無摺存款、郵寄、超商取貨付款、宅配或快遞、面交取貨付款。(21922589170747)。露天拍賣提供約翰家庭百貨的生活、居家 , 廚房與廚房用品 , 收納罐、盒等眾多商品，歡迎參觀選購！',
#  'productId': '21922589170747',
#  'brand': {'@type': 'Thing', 'name': 'top911228'},
#  'offers': {'@type': 'Offer',
#   'priceCurrency': 'TWD',
#   'price': '149',
#   'availability': 'http://schema.org/InStock'}}

# %%
pd.DataFrame(jd)
# Out:
#                          @context    @type  \
# @type          http://schema.org/  Product
# name           http://schema.org/  Product
# priceCurrency  http://schema.org/  Product
# price          http://schema.org/  Product
# availability   http://schema.org/  Product
#
#                                                             name  \
# @type          500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ04...
# name           500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ04...
# priceCurrency  500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ04...
# price          500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ04...
# availability   500ml玻璃帶卡扣密封儲物罐 無鉛透明罐 泡酒醬菜果醬罐子 五穀雜糧保鮮罐玻璃罐【ZJ04...
#
#                                                            image  \
# @type          https://img.ruten.com.tw/s1/3/9c/3b/2192258917...
# name           https://img.ruten.com.tw/s1/3/9c/3b/2192258917...
# priceCurrency  https://img.ruten.com.tw/s1/3/9c/3b/2192258917...
# ...

# %%
data = soup_re.find_all(class_="rt-store-goods-disp-mix")
#print (data)
for product in data: 
    
    print(product.find(class_ = "item-info").find('a').get('href'))
    #data[0].find(class_ = "item-info").a['href']

    print(product.find(class_ = "item-info").find('a').text)
    #data[0].find(class_ = "item-info").a.text

    print(product.find(class_ = "item-info").find(class_= "item-direct-price rt-ml-remove").text)
# Out:
# https://goods.ruten.com.tw/item/show?22001158746691
# 便攜式自行車鏈條 上油器 齒輪上油器 注油器 自行車保養自行車鏈條油 自行車工具
#
#                                           $119
#
# https://goods.ruten.com.tw/item/show?21952111158343
# 公司貨 KMC 11速 X11EL 輕量化 中空 金色 鏈條 附11速快扣 散裝
#
#                                           $845
#
# https://goods.ruten.com.tw/item/show?21952111057497
# 安卓5A充電線 快充線 USB充電線 Type C Micro  三星 OPPO ASUS傳輸線
#
#                                           $44
#
# https://goods.ruten.com.tw/item/show?21951084582184
# 自行車踏板 MG5051 輕鎂合金踏板 腳踏車腳踏 自行車腳踏 培林腳踏 合金腳踏板
#
#                                           $428
#
# https://goods.ruten.com.tw/item/show?21950038931269
# 料理玻璃油瓶 自動開關 防漏油壺 家用裝油瓶 醬油瓶 廚房用品 調味罐 油罐
#
#                                           $129
#
# https://goods.ruten.com.tw/item/show?21949986974558
# CO2充氣接頭 快速充氣瓶 CO2打氣筒 腳踏車打氣筒 CO2轉接頭 氣嘴頭 CO2轉接器 美法通用
#
#                                           $299
#
# https://goods.ruten.com.tw/item/show?21949975360847
# ...

# %%
data[0].find(class_ = "item-info").find('a').get('href')
#data[0].find(class_ = "item-info").a['href']

data[0].find(class_ = "item-info").find('a').text
#data[0].find(class_ = "item-info").a.text

data[0].find(class_ = "item-info").find(class_= "item-direct-price rt-ml-remove").text
# Out:
# '便攜式自行車鏈條 上油器 齒輪上油器 注油器 自行車保養自行車鏈條油 自行車工具'

# %%
from selenium import webdriver

# %%
chrome_path = "./chromedriver.exe" #chromedriver.exe執行檔所存在的路徑

# %%
driver = webdriver.Chrome(chrome_path)
driver.get("https://find.ruten.com.tw/s/?q=%E6%9E%9C%E9%86%AC")

# %%
driver.find_element_by_xpath("//body/div[@id='WRAPPER']/div[@id='CONTENT']/div[@class='layout-center']/div[@class='ui-search']/div[@class='block_C']/div[@id='ProdGridContainer']/dl[@class='search_form s_grid']/dd[@class='content']/dl[1]/dd[1]/div[1]/a[1]/img[1]").click
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2e8ff44f8975e32e0f135eb05197f645", element="0.5111524340508762-1")>

# %%
driver.current_url

# %%
# requests 這個 python library 有很方便的 header 和 cookie 支援


headers = {
    # User agent 路邊隨意撿一個來用

    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/32.0.1700.107 Safari/537.36',
}

cookies = {
    # 就是這個光啦

    '_ts_id':  '999999999999999999', 
}

html_re = requests.get('https://find.ruten.com.tw/s/?q=%E6%9E%9C%E9%86%AC', headers=headers, cookies=cookies)

# %%
soup_re = BeautifulSoup(html_re.content,'html.parser')

# %%
soup_re
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="zh-tw" http-equiv="Content-Language">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>搜尋結果 - 露天拍賣</title>
# <meta content="" name="description"/>
# <meta content="露天拍賣-台灣 NO.1 拍賣網站" property="og:title"/>
# <meta content="露天拍賣-台灣 NO.1 拍賣網站" property="og:description"/>
# <meta content="露天拍賣-台灣 NO.1 拍賣網站" property="og:site-name"/>
# <meta content="website" property="og:type"/>
# <link href="" rel="canonical"/>
# <link href="" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="/min/index.php?g=find-shcssv1&amp;20191206_01" rel="stylesheet" type="text/css"/>
# <script src="/min/index.php?g=find-jslibv1&amp;2017" type="text/javascript"></script>
# ...

# %%
len(soup_re.select('script'))
# Out:
# 2

# %%
soup_re.select('script').text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-49876531b064> in <module>
# ----> 1 soup_re.select('script').text.strip()
#
# AttributeError: 'list' object has no attribute 'text'

# %%
import json
jd = json.loads(soup_re.select('script')[0].text.strip())

# %%
import pandas as pd

# %%
pd.DataFrame(jd)['description']
# Out:
# @type            直購價：600元。物品狀態：全新。支付方式包含PChomePay支付連、銀行或郵局轉帳、宅配...
# name             直購價：600元。物品狀態：全新。支付方式包含PChomePay支付連、銀行或郵局轉帳、宅配...
# priceCurrency    直購價：600元。物品狀態：全新。支付方式包含PChomePay支付連、銀行或郵局轉帳、宅配...
# price            直購價：600元。物品狀態：全新。支付方式包含PChomePay支付連、銀行或郵局轉帳、宅配...
# availability     直購價：600元。物品狀態：全新。支付方式包含PChomePay支付連、銀行或郵局轉帳、宅配...
# Name: description, dtype: object

# %%
from selenium import webdriver

# %%
chrome_path = "./chromedriver.exe"   #chromedriver.exe執行檔所存在的路徑

# %%
driver = webdriver.Chrome(chrome_path)
driver.get("https://find.ruten.com.tw/s/?q=%E6%9E%9C%E9%86%AC")

# %%
driver.find_element_by_xpath("//body/div[@id='WRAPPER']/div[@id='CONTENT']/div[@class='layout-center']/div[@class='ui-search']/div[@class='block_C']/div[@id='ProdGridContainer']/dl[@class='search_form s_grid']/dd[@class='content']/dl[1]/dd[1]/div[1]/a[1]/img[1]").click()




hand = driver.window_handles

driver.switch_to_window(hand[1])

driver.close()

# %%
driver.switch_to_window(hand[0])
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: use driver.switch_to.window instead
#   """Entry point for launching an IPython kernel.

# %%
/html[1]/body[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[3]/dl[1]/dd[1]/dl[2]/dd[1]/div[1]/a[1]/img[1]

# %%
/html[1]/body[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[3]/dl[1]/dd[1]/dl[1]/dd[1]/div[1]/a[1]/img[1]

# %%
/html[1]/body[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[3]/dl[1]/dd[1]/dl[1]/dd[1]/div[1]/a[1]/img[1]
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-215-d5f6042af91a> in <module>
# ----> 1 driver.find_element_by_xpath("//body/div[@id='WRAPPER']/div[@id='CONTENT']/div[@class='layout-center']/div[@class='ui-search']/div[@class='block_C']/div[@id='ProdGridContainer']/dl[@class='search_form s_grid']/dd[@class='content']/dl[1]/dd[5]/div[1]/a[1]/img[1]")
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
driver.find_element_by_xpath("//div[contains(@class,'block_C')]//li[14]//a[1]").click()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-225-f9bffc8b04ee> in <module>
# ----> 1 driver.find_element_by_xpath("//div[contains(@class,'block_C')]//li[14]//a[1]").click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
# ...

# %%
for num in range(1,5) :
    driver.find_element_by_xpath("/html[1]/body[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[3]/dl[1]/dd[1]/dl[{}]/dd[1]/div[1]/a[1]/img[1]".format(num)).click()

# %%
driver.find_element_by_xpath("//input[@id='topSearchInput']").send_keys("果醬")

# %%
driver.find_element_by_xpath("//a[@id='topSearchButton']").click()

# %%
driver.current_url
# Out:
# 'https://find.ruten.com.tw/s/?q=%E6%9E%9C%E9%86%AC'

# %%
from selenium import webdriver
chrome_path = "./chromedriver.exe" #chromedriver.exe執行檔所存在的路徑
driver = webdriver.Chrome(chrome_path)
driver.get("https://www.ruten.com.tw/")


###  defind 研究的產品 (罐頭)

list_ = [#放罐頭名稱
        ]

for name_reach in list_ :
    
    
    ### 搜尋名稱
    driver.find_element_by_xpath("//input[@id='keyword']").send_keys(name_reach)
    ### 搜尋
    driver.find_element_by_xpath("//input[@class='rt-header-search-submit']").click()
    
    ### 切換顯示方式
    driver.find_element_by_xpath("//a[contains(@class,'list')]").click()
    
    for next_page in range(99) :
        for product in range(1,81) :

            ### click each product

            driver.find_element_by_xpath(
                "/html[1]/body[1]/div[1]/div[2]/div[1]/div[1]/div[2]/div[3]/dl[1]/dd[1]/dl[{}]/dd[1]/div[1]/a[1]/img[1]".format(product)).click()
            
            time.sleep(5)
            ### switch to current page 
            hand = driver.window_handles

            driver.switch_to_window(hand[1])

            page = driver.current_url
            ######################################
            #for ~~~~~~~


            ######################################
            driver.close()

            driver.switch_to_window(hand[0])

        
        driver.find_element_by_xpath("//div[contains(@class,'block_C')]//li[14]//a[1]").click()
